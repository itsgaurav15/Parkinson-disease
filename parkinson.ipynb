# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('parkinson_disease.csv')

# %%
df
# Out:
#       id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0      0       1  0.85247  0.71826  0.57227        240               239
# 1      0       1  0.76686  0.69481  0.53966        234               233
# 2      0       1  0.85083  0.67604  0.58982        232               231
# 3      1       0  0.41121  0.79672  0.59257        178               177
# 4      1       0  0.32790  0.79782  0.53028        236               235
# ..   ...     ...      ...      ...      ...        ...               ...
# 751  250       0  0.80903  0.56355  0.28385        417               416
# 752  250       0  0.16084  0.56499  0.59194        415               413
# 753  251       0  0.88389  0.72335  0.46815        381               380
# 754  251       0  0.83782  0.74890  0.49823        340               339
# 755  251       0  0.81304  0.76471  0.46374        340               339
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Columns: 755 entries, id to class
# dtypes: float64(749), int64(6)
# memory usage: 4.4 MB

# %%
df.describe()
# Out:
#                id      gender         PPE         DFA        RPDE   numPulses  \
# count  756.000000  756.000000  756.000000  756.000000  756.000000  756.000000
# mean   125.500000    0.515873    0.746284    0.700414    0.489058  323.972222
# std     72.793721    0.500079    0.169294    0.069718    0.137442   99.219059
# min      0.000000    0.000000    0.041551    0.543500    0.154300    2.000000
# 25%     62.750000    0.000000    0.762833    0.647053    0.386537  251.000000
# 50%    125.500000    1.000000    0.809655    0.700525    0.484355  317.000000
# 75%    188.250000    1.000000    0.834315    0.754985    0.586515  384.250000
# max    251.000000    1.000000    0.907660    0.852640    0.871230  907.000000
#
#        numPeriodsPulses  meanPeriodPulses  stdDevPeriodPulses  locPctJitter  \
# count        756.000000        756.000000          756.000000    756.000000
# mean         322.678571          0.006360            0.000383      0.002324
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# gender                       0
# PPE                          0
# DFA                          0
# RPDE                         0
#                             ..
# tqwt_kurtosisValue_dec_33    0
# tqwt_kurtosisValue_dec_34    0
# tqwt_kurtosisValue_dec_35    0
# tqwt_kurtosisValue_dec_36    0
# class                        0
# Length: 755, dtype: int64

# %% [markdown]
# Since there is no null value in dataset we will mode forward for further steps.
# since the dataset contains too many features we will remove highly correlated feature except for target feature.

# %%
columns = list(df.columns)
for col in columns:
    if col == 'class':
        continue
    filtered_columns = [col]
    for col1 in df.columns:
        if((col == col1) | (col == 'class')):
            continue
        val = df[col].corr(df[col1])
        if val > 0.7:
            columns.remove(col1)
            continue
        else:
            filtered_columns.append(col1)
            
    df = df[filtered_columns]
df.shape
# Out:
# (756, 314)

# %%
#still dataset has lot of feature so we will use only few most important feature
#using chi square test
from sklearn.preprocessing import  MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2
x = df.drop('class', axis=1)
x_norm = MinMaxScaler().fit_transform(x)
selector = SelectKBest(chi2, k=10)
selector.fit(x_norm, df['class'])
filtered_columns = selector.get_support()
filtered_data = x.loc[:, filtered_columns]
filtered_data['class'] = df['class']
df = filtered_data
df.shape
# Out:
# C:\Users\Gaura\AppData\Local\Temp\ipykernel_532\1884685770.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['class'] = df['class']
# (756, 11)

# %%
df
# Out:
#      tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_26  \
# 0                       1.5620                     1.6058
# 1                       1.5589                     1.5772
# 2                       1.5643                     1.5921
# 3                       3.7805                     1.8829
# 4                       6.1727                     1.8821
# ..                         ...                        ...
# 751                     3.0706                    10.1906
# 752                     1.9704                    22.4043
# 753                    51.5607                     2.3279
# 754                    19.1607                     1.6052
# 755                    62.9927                     1.6820
#
#      tqwt_kurtosisValue_dec_25  tqwt_entropy_shannon_dec_15  \
# 0                       2.0062                     174.6920
# 1                       2.0470                     140.8136
# 2                       3.2597                      84.8129
# ...

# %%
x_count = df['class'].value_counts()
# plt.pie(x.values,
#         labels = x.index,
#         autopct='%1.1f%%')
# plt.show()
x_count
# Out:
# class
# 1    564
# 0    192
# Name: count, dtype: int64

# %% [markdown]
# The dataset is imbalnce so we will use SMOTE for balancing the dataset.

# %%
from sklearn.model_selection import train_test_split
x=df.drop('class',axis=1)
y=df['class']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10)
x_train.shape,x_test.shape
# Out:
# ((604, 10), (152, 10))

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
x, y = smote.fit_resample(x_train, y_train)
x.shape,y.shape
# Out:
# ((892, 10), (892,))

# %% [markdown]
# Model Training

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

models = {
    "Random Forest": RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=200, random_state=42),
    "SVM": SVC(kernel='rbf', probability=True),
    "KNN": KNeighborsClassifier(n_neighbors=5),
    "Logistic Regression": LogisticRegression(max_iter=500)
}

cv_results = {}

for name, model in models.items():
    scores = cross_val_score(model, x, y, cv=5, scoring='accuracy')
    cv_results[name] = np.mean(scores)
    print(f"{name}: {np.mean(scores):.4f}")

best_model_name = max(cv_results, key=cv_results.get)
best_model = models[best_model_name]
best_model.fit(x, y) 

import pickle
pickle.dump(best_model, open("best_model.pkl", "wb"))
print(f"Best model is {best_model_name} with accuracy {cv_results[best_model_name]:.4f}")
# Out:
# Random Forest: 0.8891
# Gradient Boosting: 0.8599
# SVM: 0.7208
# KNN: 0.7724
# Logistic Regression: 0.7522
# Best model is Random Forest with accuracy 0.8891
